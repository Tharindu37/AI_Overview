# %% [markdown]
# #### Machine Learning Models
# 1. Instance Based Learning(Lazy Learning)
# 2. Model Based Learning (Eager Learning)

# %% [markdown]
# ##### Instance Based Learning
# Example: K-Nearesr Neighbours, Locally Weighted Regression

# %% [markdown]
# ##### Model Based Learning
# Example: Linear Regression, Logistic Regression, Decision Tree, Support Vector Machine
